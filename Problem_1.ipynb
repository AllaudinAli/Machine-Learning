# %% [markdown]
# <a href="https://colab.research.google.com/github/AllaudinAli/Machine-Learning/blob/main/Problem_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem 1: (b)
import pandas as pd
import numpy as np
xdic={'x': {11: 300, 12: 170, 13: 288, 14: 360, 15: 319, 16: 330,
17: 520, 18: 345, 19: 399, 20: 479}}
ydic={'y': {11: 305, 12: 270, 13: 360, 14: 370, 15: 379, 16: 400,
17: 407, 18: 450, 19: 450, 20: 485}}
x=pd.DataFrame.from_dict(xdic)
y=pd.DataFrame.from_dict(ydic)
x_seq = np.linspace(x.min(),x.max(),300).reshape(-1,1)

import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=5)
x_poly = poly.fit_transform(x)
polyreg = LinearRegression()
polyreg.fit(x_poly, y)

import matplotlib.pyplot as plt
plt.figure()
plt.scatter(x,y)
plt.plot(x_seq,polyreg.predict(poly.fit_transform(x_seq)),color="black")
plt.title("Polynomial regression with degree 2" )
plt.show()

# %%
#Problem #1 (c)
poly = PolynomialFeatures(degree=1)
x_poly = poly.fit_transform(x)
polyreg = LinearRegression()
polyreg.fit(x_poly, y)
plt.figure()
plt.scatter(x,y)
plt.plot(x_seq,polyreg.predict(poly.fit_transform(x_seq)),color="black")
plt.title("Polynomial regression with degree 1" )
plt.show()

# %%
#Problem #1 (c)
poly = PolynomialFeatures(degree=3)
x_poly = poly.fit_transform(x)
polyreg = LinearRegression()
polyreg.fit(x_poly, y)
plt.figure()
plt.scatter(x,y)
plt.plot(x_seq,polyreg.predict(poly.fit_transform(x_seq)),color="black")
plt.title("Polynomial regression with degree 3" )
plt.show()

# %%
#Problem #1 (c)
poly = PolynomialFeatures(degree=4)
x_poly = poly.fit_transform(x)
polyreg = LinearRegression()
polyreg.fit(x_poly, y)
plt.figure()
plt.scatter(x,y)
plt.plot(x_seq,polyreg.predict(poly.fit_transform(x_seq)),color="black")
plt.title("Polynomial regression with degree 4" )
plt.show()

# %%
#Problem #1 (c)
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)
polyreg = LinearRegression()
polyreg.fit(x_poly, y)
plt.figure()
plt.scatter(x,y)
plt.plot(x_seq,polyreg.predict(poly.fit_transform(x_seq)),color="black")
plt.title("Polynomial regression with degree 5" )
plt.show()
